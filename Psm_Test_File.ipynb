# %% [markdown]
# ### 1 Read test files

# %%
import pandas as pd
import matplotlib.pyplot as plt

psm_test = pd.read_csv('datasets/psm_test.csv')
s
# Read label files
psm_test_label = pd.read_csv('datasets/psm_test_label.csv')

# %% [markdown]
# ### 2. Draw time series plots with anomaly regions:

# %%
plt.plot(psm_test.index, psm_test.iloc[:, 1])  # Assuming the timestamps are not provided in the dataset
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Time Series Data')

# # Highlight anomaly regions
# for i in range(len(psm_test_label)):
#     plt.axvline(x=psm_test_label.iloc[i, 0], color='red', linestyle='--')  # Assuming the anomaly points are specified by index
# plt.show()
# Out:
# Text(0.5, 1.0, 'Time Series Data')

# %% [markdown]
# ### 3. Perform EDA and find out root cause

# %%
plt.figure(figsize=(10, 6))
plt.hist(psm_test.iloc[:, 1], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Visualize the time series data
plt.figure(figsize=(12, 6))
plt.plot(psm_test.index, psm_test.iloc[:, 1], color='blue')
plt.title('Time Series Data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. Find out the variables which are the root cause for the anomaly:

# %%
    # Extract anomaly regions based on indices provided in the label file
    anomaly_indices = psm_test_label.iloc[:, 0].tolist()
    anomaly_values = psm_test.iloc[anomaly_indices, 1]

    # Calculate summary statistics for anomaly regions
    anomaly_stats = anomaly_values.describe()

    # Calculate summary statistics for non-anomaly regions
    non_anomaly_values = psm_test.drop(anomaly_indices, axis=0).iloc[:, 1]
    non_anomaly_stats = non_anomaly_values.describe()

    # Compare the statistics
    print("Summary statistics for anomaly regions:")
    print(anomaly_stats)
    print("\nSummary statistics for non-anomaly regions:")
    print(non_anomaly_stats)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Extract anomaly regions based on indices provided in the label file
#       2 anomaly_indices = psm_test_label.iloc[:, 0].tolist()
# ----> 3 anomaly_values = psm_test.iloc[anomaly_indices, 1]
#       5 # Calculate summary statistics for anomaly regions
#       6 anomaly_stats = anomaly_values.describe()
#
# File D:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File D:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
# ...
